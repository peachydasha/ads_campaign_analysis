# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Работа с данными

# %% [markdown]
# Считаем данные из двух датасетов и объединим их

# %%
control = pd.read_csv('control_group.csv', sep=';')
test = pd.read_csv('test_group.csv', sep=';')

# %%
total = pd.concat([control, test], keys = ['control', 'test'])
total
# Out:
#                Campaign Name        Date  Spend [USD]  # of Impressions  \
# control 0   Control Campaign   1.08.2019         2280           82702.0
#         1   Control Campaign   2.08.2019         1757          121040.0
#         2   Control Campaign   3.08.2019         2343          131711.0
#         3   Control Campaign   4.08.2019         1940           72878.0
#         4   Control Campaign   5.08.2019         1835               NaN
#         5   Control Campaign   6.08.2019         3083          109076.0
#         6   Control Campaign   7.08.2019         2544          142123.0
#         7   Control Campaign   8.08.2019         1900           90939.0
#         8   Control Campaign   9.08.2019         2813          121332.0
#         9   Control Campaign  10.08.2019         2149          117624.0
#         10  Control Campaign  11.08.2019         2490          115247.0
#         11  Control Campaign  12.08.2019         2319          116639.0
#         12  Control Campaign  13.08.2019         2697           82847.0
#         13  Control Campaign  14.08.2019         1875          145248.0
#         14  Control Campaign  15.08.2019         2774          132845.0
#         15  Control Campaign  16.08.2019         2024           71274.0
#         16  Control Campaign  17.08.2019         2177          119612.0
#         17  Control Campaign  18.08.2019         1876          108452.0
#         18  Control Campaign  19.08.2019         2596          107890.0
#         19  Control Campaign  20.08.2019         2675          113430.0
#         20  Control Campaign  21.08.2019         1803           74654.0
#         21  Control Campaign  22.08.2019         2939          105705.0
#         22  Control Campaign  23.08.2019         2496          129880.0
#         23  Control Campaign  24.08.2019         1892           72515.0
#         24  Control Campaign  25.08.2019         1962          117006.0
#         25  Control Campaign  26.08.2019         2233          124897.0
#         26  Control Campaign  27.08.2019         2061          104678.0
#         27  Control Campaign  28.08.2019         2421          141654.0
#         28  Control Campaign  29.08.2019         2375           92029.0
#         29  Control Campaign  30.08.2019         2324          111306.0
# test    0      Test Campaign   1.08.2019         3008           39550.0
#         1      Test Campaign   2.08.2019         2542          100719.0
#         2      Test Campaign   3.08.2019         2365           70263.0
#         3      Test Campaign   4.08.2019         2710           78451.0
#         4      Test Campaign   5.08.2019         2297          114295.0
#         5      Test Campaign   6.08.2019         2458           42684.0
#         6      Test Campaign   7.08.2019         2838           53986.0
#         7      Test Campaign   8.08.2019         2916           33669.0
#         8      Test Campaign   9.08.2019         2652           45511.0
#         9      Test Campaign  10.08.2019         2790           95054.0
#         10     Test Campaign  11.08.2019         2420           83633.0
#         11     Test Campaign  12.08.2019         2831          124591.0
#         12     Test Campaign  13.08.2019         1972           65827.0
#         13     Test Campaign  14.08.2019         2537           56304.0
#         14     Test Campaign  15.08.2019         2516           94338.0
#         15     Test Campaign  16.08.2019         3076          106584.0
#         16     Test Campaign  17.08.2019         1968           95843.0
#         17     Test Campaign  18.08.2019         1979           53632.0
#         18     Test Campaign  19.08.2019         2626           22521.0
#         19     Test Campaign  20.08.2019         2712           39470.0
#         20     Test Campaign  21.08.2019         3112          133771.0
#         21     Test Campaign  22.08.2019         2899           34752.0
#         22     Test Campaign  23.08.2019         2407           60286.0
#         23     Test Campaign  24.08.2019         2078           36650.0
#         24     Test Campaign  25.08.2019         2928          120576.0
#         25     Test Campaign  26.08.2019         2311           80841.0
#         26     Test Campaign  27.08.2019         2915          111469.0
#         27     Test Campaign  28.08.2019         2247           54627.0
#         28     Test Campaign  29.08.2019         2805           67444.0
#         29     Test Campaign  30.08.2019         1977          120203.0
#
#                Reach  # of Website Clicks  # of Searches  # of View Content  \
# control 0    56930.0               7016.0         2290.0             2159.0
#         1   102513.0               8110.0         2033.0             1841.0
#         2   110862.0               6508.0         1737.0             1549.0
#         3    61235.0               3065.0         1042.0              982.0
#         4        NaN                  NaN            NaN                NaN
#         5    87998.0               4028.0         1709.0             1249.0
#         6   127852.0               2640.0         1388.0             1106.0
#         7    65217.0               7260.0         3047.0             2746.0
#         8    94896.0               6198.0         2487.0             2179.0
#         9    91257.0               2277.0         2475.0             1984.0
#         10   95843.0               8137.0         2941.0             2486.0
#         11  100189.0               2993.0         1397.0             1147.0
#         12   68214.0               6554.0         2390.0             1975.0
#         13  118632.0               4521.0         1209.0             1149.0
#         14  102479.0               4896.0         1179.0             1005.0
#         15   42859.0               5224.0         2427.0             2158.0
#         16  106518.0               6628.0         1756.0             1642.0
#         17   96518.0               7253.0         2447.0             2115.0
#         18   81268.0               3706.0         2483.0             2098.0
#         19   78625.0               2578.0         1001.0              848.0
#         20   59873.0               5691.0         2711.0             2496.0
#         21   86218.0               6843.0         3102.0             2988.0
#         22  109413.0               4410.0         2896.0             2496.0
#         23   51987.0               4085.0         1274.0             1149.0
#         24  100398.0               4234.0         2423.0             2096.0
#         25   98432.0               5435.0         2847.0             2421.0
#         26   91579.0               4941.0         3549.0             3249.0
#         27  125874.0               6287.0         1672.0             1589.0
#         28   74192.0               8127.0         4891.0             4219.0
#         29   88632.0               4658.0         1615.0             1249.0
# test    0    35820.0               3038.0         1946.0             1069.0
#         1    91236.0               4657.0         2359.0             1548.0
#         2    45198.0               7885.0         2572.0             2367.0
#         3    25937.0               4216.0         2216.0             1437.0
#         4    95138.0               5863.0         2106.0              858.0
#         5    31489.0               7488.0         1854.0             1073.0
#         6    42148.0               4221.0         2733.0             2182.0
#         7    20149.0               7184.0         2867.0             2194.0
#         8    31598.0               8259.0         2899.0             2761.0
#         9    79632.0               8125.0         2312.0             1804.0
#         10   71286.0               3750.0         2893.0             2617.0
#         11   10598.0               8264.0         2081.0             1992.0
#         12   49531.0               7568.0         2213.0             2058.0
#         13   25982.0               3993.0         1979.0             1059.0
#         14   76219.0               4993.0         2537.0             1609.0
#         15   81389.0               6800.0         2661.0             2594.0
#         16   54389.0               7910.0         1995.0             1576.0
#         17   43241.0               6909.0         2824.0             2522.0
#         18   10698.0               7617.0         2924.0             2801.0
#         19   31893.0               6050.0         2061.0             1894.0
#         20  109834.0               5471.0         1995.0             1868.0
#         21   27932.0               4431.0         1983.0             1131.0
#         22   49329.0               5077.0         2592.0             2004.0
#         23   30489.0               7156.0         2687.0             2427.0
#         24  105978.0               3596.0         2937.0             2551.0
#         25   61589.0               3820.0         2037.0             1046.0
#         26   92159.0               6435.0         2976.0             2552.0
#         27   41267.0               8144.0         2432.0             1281.0
#         28   43219.0               7651.0         1920.0             1240.0
#         29   89380.0               4399.0         2978.0             1625.0
#
#             # of Add to Cart  # of Purchase
# control 0             1819.0          618.0
#         1             1219.0          511.0
#         2             1134.0          372.0
#         3             1183.0          340.0
#         4                NaN            NaN
#         5              784.0          764.0
#         6             1166.0          499.0
#         7              930.0          462.0
#         8              645.0          501.0
#         9             1629.0          734.0
#         10            1887.0          475.0
#         11            1439.0          794.0
#         12            1794.0          766.0
#         13            1339.0          788.0
#         14            1641.0          366.0
#         15            1613.0          438.0
#         16             878.0          222.0
#         17            1695.0          243.0
#         18             908.0          542.0
#         19            1709.0          299.0
#         20            1460.0          800.0
#         21             819.0          387.0
#         22            1913.0          766.0
#         23            1146.0          585.0
#         24             883.0          386.0
#         25            1448.0          251.0
#         26             980.0          605.0
#         27            1711.0          643.0
#         28            1486.0          334.0
#         29             442.0          670.0
# test    0              894.0          255.0
#         1              879.0          677.0
#         2             1268.0          578.0
#         3              566.0          340.0
#         4              956.0          768.0
#         5              882.0          488.0
#         6             1301.0          890.0
#         7             1240.0          431.0
#         8             1200.0          845.0
#         9              424.0          275.0
#         10            1075.0          668.0
#         11            1382.0          709.0
#         12            1391.0          812.0
#         13             779.0          340.0
#         14            1090.0          398.0
#         15            1059.0          487.0
#         16             383.0          238.0
#         17             461.0          257.0
#         18             788.0          512.0
#         19            1047.0          730.0
#         20             278.0          245.0
#         21             367.0          276.0
#         22             632.0          473.0
#         23             327.0          269.0
#         24            1228.0          651.0
#         25             346.0          284.0
#         26             992.0          771.0
#         27            1009.0          721.0
#         28            1168.0          677.0
#         29            1034.0          572.0

# %% [markdown]
# Посмотрим на пропущенные значения...

# %%
total.isnull().sum()
# Out:
# Campaign Name          0
# Date                   0
# Spend [USD]            0
# # of Impressions       1
# Reach                  1
# # of Website Clicks    1
# # of Searches          1
# # of View Content      1
# # of Add to Cart       1
# # of Purchase          1
# dtype: int64

# %% [markdown]
# ... и заменим их средним значением

# %%
for x in ['# of Impressions', 'Reach', '# of Website Clicks', '# of Searches','# of View Content', '# of Add to Cart','# of Purchase']:
    total.loc[total[total[x].isnull()].index, x] = total[total[x].isnull() == False][x].mean()
total
# Out:
#                Campaign Name        Date  Spend [USD]  # of Impressions  \
# control 0   Control Campaign   1.08.2019         2280      82702.000000
#         1   Control Campaign   2.08.2019         1757     121040.000000
#         2   Control Campaign   3.08.2019         2343     131711.000000
#         3   Control Campaign   4.08.2019         1940      72878.000000
#         4   Control Campaign   5.08.2019         1835      91775.881356
#         5   Control Campaign   6.08.2019         3083     109076.000000
#         6   Control Campaign   7.08.2019         2544     142123.000000
#         7   Control Campaign   8.08.2019         1900      90939.000000
#         8   Control Campaign   9.08.2019         2813     121332.000000
#         9   Control Campaign  10.08.2019         2149     117624.000000
#         10  Control Campaign  11.08.2019         2490     115247.000000
#         11  Control Campaign  12.08.2019         2319     116639.000000
#         12  Control Campaign  13.08.2019         2697      82847.000000
#         13  Control Campaign  14.08.2019         1875     145248.000000
#         14  Control Campaign  15.08.2019         2774     132845.000000
#         15  Control Campaign  16.08.2019         2024      71274.000000
#         16  Control Campaign  17.08.2019         2177     119612.000000
#         17  Control Campaign  18.08.2019         1876     108452.000000
#         18  Control Campaign  19.08.2019         2596     107890.000000
#         19  Control Campaign  20.08.2019         2675     113430.000000
#         20  Control Campaign  21.08.2019         1803      74654.000000
#         21  Control Campaign  22.08.2019         2939     105705.000000
#         22  Control Campaign  23.08.2019         2496     129880.000000
#         23  Control Campaign  24.08.2019         1892      72515.000000
#         24  Control Campaign  25.08.2019         1962     117006.000000
#         25  Control Campaign  26.08.2019         2233     124897.000000
#         26  Control Campaign  27.08.2019         2061     104678.000000
#         27  Control Campaign  28.08.2019         2421     141654.000000
#         28  Control Campaign  29.08.2019         2375      92029.000000
#         29  Control Campaign  30.08.2019         2324     111306.000000
# test    0      Test Campaign   1.08.2019         3008      39550.000000
#         1      Test Campaign   2.08.2019         2542     100719.000000
#         2      Test Campaign   3.08.2019         2365      70263.000000
#         3      Test Campaign   4.08.2019         2710      78451.000000
#         4      Test Campaign   5.08.2019         2297     114295.000000
#         5      Test Campaign   6.08.2019         2458      42684.000000
#         6      Test Campaign   7.08.2019         2838      53986.000000
#         7      Test Campaign   8.08.2019         2916      33669.000000
#         8      Test Campaign   9.08.2019         2652      45511.000000
#         9      Test Campaign  10.08.2019         2790      95054.000000
#         10     Test Campaign  11.08.2019         2420      83633.000000
#         11     Test Campaign  12.08.2019         2831     124591.000000
#         12     Test Campaign  13.08.2019         1972      65827.000000
#         13     Test Campaign  14.08.2019         2537      56304.000000
#         14     Test Campaign  15.08.2019         2516      94338.000000
#         15     Test Campaign  16.08.2019         3076     106584.000000
#         16     Test Campaign  17.08.2019         1968      95843.000000
#         17     Test Campaign  18.08.2019         1979      53632.000000
#         18     Test Campaign  19.08.2019         2626      22521.000000
#         19     Test Campaign  20.08.2019         2712      39470.000000
#         20     Test Campaign  21.08.2019         3112     133771.000000
#         21     Test Campaign  22.08.2019         2899      34752.000000
#         22     Test Campaign  23.08.2019         2407      60286.000000
#         23     Test Campaign  24.08.2019         2078      36650.000000
#         24     Test Campaign  25.08.2019         2928     120576.000000
#         25     Test Campaign  26.08.2019         2311      80841.000000
#         26     Test Campaign  27.08.2019         2915     111469.000000
#         27     Test Campaign  28.08.2019         2247      54627.000000
#         28     Test Campaign  29.08.2019         2805      67444.000000
#         29     Test Campaign  30.08.2019         1977     120203.000000
#
#                     Reach  # of Website Clicks  # of Searches  \
# control 0    56930.000000           7016.00000    2290.000000
#         1   102513.000000           8110.00000    2033.000000
#         2   110862.000000           6508.00000    1737.000000
#         3    61235.000000           3065.00000    1042.000000
#         4    70868.644068           5682.59322    2321.813559
#         5    87998.000000           4028.00000    1709.000000
#         6   127852.000000           2640.00000    1388.000000
#         7    65217.000000           7260.00000    3047.000000
#         8    94896.000000           6198.00000    2487.000000
#         9    91257.000000           2277.00000    2475.000000
#         10   95843.000000           8137.00000    2941.000000
#         11  100189.000000           2993.00000    1397.000000
#         12   68214.000000           6554.00000    2390.000000
#         13  118632.000000           4521.00000    1209.000000
#         14  102479.000000           4896.00000    1179.000000
#         15   42859.000000           5224.00000    2427.000000
#         16  106518.000000           6628.00000    1756.000000
#         17   96518.000000           7253.00000    2447.000000
#         18   81268.000000           3706.00000    2483.000000
#         19   78625.000000           2578.00000    1001.000000
#         20   59873.000000           5691.00000    2711.000000
#         21   86218.000000           6843.00000    3102.000000
#         22  109413.000000           4410.00000    2896.000000
#         23   51987.000000           4085.00000    1274.000000
#         24  100398.000000           4234.00000    2423.000000
#         25   98432.000000           5435.00000    2847.000000
#         26   91579.000000           4941.00000    3549.000000
#         27  125874.000000           6287.00000    1672.000000
#         28   74192.000000           8127.00000    4891.000000
#         29   88632.000000           4658.00000    1615.000000
# test    0    35820.000000           3038.00000    1946.000000
#         1    91236.000000           4657.00000    2359.000000
#         2    45198.000000           7885.00000    2572.000000
#         3    25937.000000           4216.00000    2216.000000
#         4    95138.000000           5863.00000    2106.000000
#         5    31489.000000           7488.00000    1854.000000
#         6    42148.000000           4221.00000    2733.000000
#         7    20149.000000           7184.00000    2867.000000
#         8    31598.000000           8259.00000    2899.000000
#         9    79632.000000           8125.00000    2312.000000
#         10   71286.000000           3750.00000    2893.000000
#         11   10598.000000           8264.00000    2081.000000
#         12   49531.000000           7568.00000    2213.000000
#         13   25982.000000           3993.00000    1979.000000
#         14   76219.000000           4993.00000    2537.000000
#         15   81389.000000           6800.00000    2661.000000
#         16   54389.000000           7910.00000    1995.000000
#         17   43241.000000           6909.00000    2824.000000
#         18   10698.000000           7617.00000    2924.000000
#         19   31893.000000           6050.00000    2061.000000
#         20  109834.000000           5471.00000    1995.000000
#         21   27932.000000           4431.00000    1983.000000
#         22   49329.000000           5077.00000    2592.000000
#         23   30489.000000           7156.00000    2687.000000
#         24  105978.000000           3596.00000    2937.000000
#         25   61589.000000           3820.00000    2037.000000
#         26   92159.000000           6435.00000    2976.000000
#         27   41267.000000           8144.00000    2432.000000
#         28   43219.000000           7651.00000    1920.000000
#         29   89380.000000           4399.00000    2978.000000
#
#             # of View Content  # of Add to Cart  # of Purchase
# control 0         2159.000000       1819.000000          618.0
#         1         1841.000000       1219.000000          511.0
#         2         1549.000000       1134.000000          372.0
#         3          982.000000       1183.000000          340.0
#         4         1900.169492       1087.220339          522.0
#         5         1249.000000        784.000000          764.0
#         6         1106.000000       1166.000000          499.0
#         7         2746.000000        930.000000          462.0
#         8         2179.000000        645.000000          501.0
#         9         1984.000000       1629.000000          734.0
#         10        2486.000000       1887.000000          475.0
#         11        1147.000000       1439.000000          794.0
#         12        1975.000000       1794.000000          766.0
#         13        1149.000000       1339.000000          788.0
#         14        1005.000000       1641.000000          366.0
#         15        2158.000000       1613.000000          438.0
#         16        1642.000000        878.000000          222.0
#         17        2115.000000       1695.000000          243.0
#         18        2098.000000        908.000000          542.0
#         19         848.000000       1709.000000          299.0
#         20        2496.000000       1460.000000          800.0
#         21        2988.000000        819.000000          387.0
#         22        2496.000000       1913.000000          766.0
#         23        1149.000000       1146.000000          585.0
#         24        2096.000000        883.000000          386.0
#         25        2421.000000       1448.000000          251.0
#         26        3249.000000        980.000000          605.0
#         27        1589.000000       1711.000000          643.0
#         28        4219.000000       1486.000000          334.0
#         29        1249.000000        442.000000          670.0
# test    0         1069.000000        894.000000          255.0
#         1         1548.000000        879.000000          677.0
#         2         2367.000000       1268.000000          578.0
#         3         1437.000000        566.000000          340.0
#         4          858.000000        956.000000          768.0
#         5         1073.000000        882.000000          488.0
#         6         2182.000000       1301.000000          890.0
#         7         2194.000000       1240.000000          431.0
#         8         2761.000000       1200.000000          845.0
#         9         1804.000000        424.000000          275.0
#         10        2617.000000       1075.000000          668.0
#         11        1992.000000       1382.000000          709.0
#         12        2058.000000       1391.000000          812.0
#         13        1059.000000        779.000000          340.0
#         14        1609.000000       1090.000000          398.0
#         15        2594.000000       1059.000000          487.0
#         16        1576.000000        383.000000          238.0
#         17        2522.000000        461.000000          257.0
#         18        2801.000000        788.000000          512.0
#         19        1894.000000       1047.000000          730.0
#         20        1868.000000        278.000000          245.0
#         21        1131.000000        367.000000          276.0
#         22        2004.000000        632.000000          473.0
#         23        2427.000000        327.000000          269.0
#         24        2551.000000       1228.000000          651.0
#         25        1046.000000        346.000000          284.0
#         26        2552.000000        992.000000          771.0
#         27        1281.000000       1009.000000          721.0
#         28        1240.000000       1168.000000          677.0
#         29        1625.000000       1034.000000          572.0

# %% [markdown]
# Теперь расчитаем некоторые метрики, которые могли бы помочь выдвинуть нам гипотезы, которые впоследствии будут проверены статистическими тестами. Это будут метрики CAC, CPC, CTR, Conversion Rate с целевым действием "Клик на рекламу" и Conversion Rate с целевым действием "Покупка на сайте"

# %%
total['CAC'] = total['Spend [USD]'] / total['# of Purchase'] #supposing all purchases were made by new customers
total['CPC'] = total['Spend [USD]'] / total['# of Website Clicks']
total['CTR'] = total['# of Website Clicks'] / total['# of Impressions'] * 100
total['Conversion Rate Web Clicks'] = total['# of Website Clicks'] / total['Reach'] * 100
total['Conversion Rate Purchase'] = total['# of Purchase'] / total['# of Website Clicks'] * 100
total
# Out:
#                Campaign Name        Date  Spend [USD]  # of Impressions  \
# control 0   Control Campaign   1.08.2019         2280      82702.000000
#         1   Control Campaign   2.08.2019         1757     121040.000000
#         2   Control Campaign   3.08.2019         2343     131711.000000
#         3   Control Campaign   4.08.2019         1940      72878.000000
#         4   Control Campaign   5.08.2019         1835      91775.881356
#         5   Control Campaign   6.08.2019         3083     109076.000000
#         6   Control Campaign   7.08.2019         2544     142123.000000
#         7   Control Campaign   8.08.2019         1900      90939.000000
#         8   Control Campaign   9.08.2019         2813     121332.000000
#         9   Control Campaign  10.08.2019         2149     117624.000000
#         10  Control Campaign  11.08.2019         2490     115247.000000
#         11  Control Campaign  12.08.2019         2319     116639.000000
#         12  Control Campaign  13.08.2019         2697      82847.000000
#         13  Control Campaign  14.08.2019         1875     145248.000000
#         14  Control Campaign  15.08.2019         2774     132845.000000
#         15  Control Campaign  16.08.2019         2024      71274.000000
#         16  Control Campaign  17.08.2019         2177     119612.000000
#         17  Control Campaign  18.08.2019         1876     108452.000000
#         18  Control Campaign  19.08.2019         2596     107890.000000
#         19  Control Campaign  20.08.2019         2675     113430.000000
#         20  Control Campaign  21.08.2019         1803      74654.000000
#         21  Control Campaign  22.08.2019         2939     105705.000000
#         22  Control Campaign  23.08.2019         2496     129880.000000
#         23  Control Campaign  24.08.2019         1892      72515.000000
#         24  Control Campaign  25.08.2019         1962     117006.000000
#         25  Control Campaign  26.08.2019         2233     124897.000000
#         26  Control Campaign  27.08.2019         2061     104678.000000
#         27  Control Campaign  28.08.2019         2421     141654.000000
#         28  Control Campaign  29.08.2019         2375      92029.000000
#         29  Control Campaign  30.08.2019         2324     111306.000000
# test    0      Test Campaign   1.08.2019         3008      39550.000000
#         1      Test Campaign   2.08.2019         2542     100719.000000
#         2      Test Campaign   3.08.2019         2365      70263.000000
#         3      Test Campaign   4.08.2019         2710      78451.000000
#         4      Test Campaign   5.08.2019         2297     114295.000000
#         5      Test Campaign   6.08.2019         2458      42684.000000
#         6      Test Campaign   7.08.2019         2838      53986.000000
#         7      Test Campaign   8.08.2019         2916      33669.000000
#         8      Test Campaign   9.08.2019         2652      45511.000000
#         9      Test Campaign  10.08.2019         2790      95054.000000
#         10     Test Campaign  11.08.2019         2420      83633.000000
#         11     Test Campaign  12.08.2019         2831     124591.000000
#         12     Test Campaign  13.08.2019         1972      65827.000000
#         13     Test Campaign  14.08.2019         2537      56304.000000
#         14     Test Campaign  15.08.2019         2516      94338.000000
#         15     Test Campaign  16.08.2019         3076     106584.000000
#         16     Test Campaign  17.08.2019         1968      95843.000000
#         17     Test Campaign  18.08.2019         1979      53632.000000
#         18     Test Campaign  19.08.2019         2626      22521.000000
#         19     Test Campaign  20.08.2019         2712      39470.000000
#         20     Test Campaign  21.08.2019         3112     133771.000000
#         21     Test Campaign  22.08.2019         2899      34752.000000
#         22     Test Campaign  23.08.2019         2407      60286.000000
#         23     Test Campaign  24.08.2019         2078      36650.000000
#         24     Test Campaign  25.08.2019         2928     120576.000000
#         25     Test Campaign  26.08.2019         2311      80841.000000
#         26     Test Campaign  27.08.2019         2915     111469.000000
#         27     Test Campaign  28.08.2019         2247      54627.000000
#         28     Test Campaign  29.08.2019         2805      67444.000000
#         29     Test Campaign  30.08.2019         1977     120203.000000
#
#                     Reach  # of Website Clicks  # of Searches  \
# control 0    56930.000000           7016.00000    2290.000000
#         1   102513.000000           8110.00000    2033.000000
#         2   110862.000000           6508.00000    1737.000000
#         3    61235.000000           3065.00000    1042.000000
#         4    70868.644068           5682.59322    2321.813559
#         5    87998.000000           4028.00000    1709.000000
#         6   127852.000000           2640.00000    1388.000000
#         7    65217.000000           7260.00000    3047.000000
#         8    94896.000000           6198.00000    2487.000000
#         9    91257.000000           2277.00000    2475.000000
#         10   95843.000000           8137.00000    2941.000000
#         11  100189.000000           2993.00000    1397.000000
#         12   68214.000000           6554.00000    2390.000000
#         13  118632.000000           4521.00000    1209.000000
#         14  102479.000000           4896.00000    1179.000000
#         15   42859.000000           5224.00000    2427.000000
#         16  106518.000000           6628.00000    1756.000000
#         17   96518.000000           7253.00000    2447.000000
#         18   81268.000000           3706.00000    2483.000000
#         19   78625.000000           2578.00000    1001.000000
#         20   59873.000000           5691.00000    2711.000000
#         21   86218.000000           6843.00000    3102.000000
#         22  109413.000000           4410.00000    2896.000000
#         23   51987.000000           4085.00000    1274.000000
#         24  100398.000000           4234.00000    2423.000000
#         25   98432.000000           5435.00000    2847.000000
#         26   91579.000000           4941.00000    3549.000000
#         27  125874.000000           6287.00000    1672.000000
#         28   74192.000000           8127.00000    4891.000000
#         29   88632.000000           4658.00000    1615.000000
# test    0    35820.000000           3038.00000    1946.000000
#         1    91236.000000           4657.00000    2359.000000
#         2    45198.000000           7885.00000    2572.000000
#         3    25937.000000           4216.00000    2216.000000
#         4    95138.000000           5863.00000    2106.000000
#         5    31489.000000           7488.00000    1854.000000
#         6    42148.000000           4221.00000    2733.000000
#         7    20149.000000           7184.00000    2867.000000
#         8    31598.000000           8259.00000    2899.000000
#         9    79632.000000           8125.00000    2312.000000
#         10   71286.000000           3750.00000    2893.000000
#         11   10598.000000           8264.00000    2081.000000
#         12   49531.000000           7568.00000    2213.000000
#         13   25982.000000           3993.00000    1979.000000
#         14   76219.000000           4993.00000    2537.000000
#         15   81389.000000           6800.00000    2661.000000
#         16   54389.000000           7910.00000    1995.000000
#         17   43241.000000           6909.00000    2824.000000
#         18   10698.000000           7617.00000    2924.000000
#         19   31893.000000           6050.00000    2061.000000
#         20  109834.000000           5471.00000    1995.000000
#         21   27932.000000           4431.00000    1983.000000
#         22   49329.000000           5077.00000    2592.000000
#         23   30489.000000           7156.00000    2687.000000
#         24  105978.000000           3596.00000    2937.000000
#         25   61589.000000           3820.00000    2037.000000
#         26   92159.000000           6435.00000    2976.000000
#         27   41267.000000           8144.00000    2432.000000
#         28   43219.000000           7651.00000    1920.000000
#         29   89380.000000           4399.00000    2978.000000
#
#             # of View Content  # of Add to Cart  # of Purchase        CAC  \
# control 0         2159.000000       1819.000000          618.0   3.689320
#         1         1841.000000       1219.000000          511.0   3.438356
#         2         1549.000000       1134.000000          372.0   6.298387
#         3          982.000000       1183.000000          340.0   5.705882
#         4         1900.169492       1087.220339          522.0   3.515326
#         5         1249.000000        784.000000          764.0   4.035340
#         6         1106.000000       1166.000000          499.0   5.098196
#         7         2746.000000        930.000000          462.0   4.112554
#         8         2179.000000        645.000000          501.0   5.614770
#         9         1984.000000       1629.000000          734.0   2.927793
#         10        2486.000000       1887.000000          475.0   5.242105
#         11        1147.000000       1439.000000          794.0   2.920655
#         12        1975.000000       1794.000000          766.0   3.520888
#         13        1149.000000       1339.000000          788.0   2.379442
#         14        1005.000000       1641.000000          366.0   7.579235
#         15        2158.000000       1613.000000          438.0   4.621005
#         16        1642.000000        878.000000          222.0   9.806306
#         17        2115.000000       1695.000000          243.0   7.720165
#         18        2098.000000        908.000000          542.0   4.789668
#         19         848.000000       1709.000000          299.0   8.946488
#         20        2496.000000       1460.000000          800.0   2.253750
#         21        2988.000000        819.000000          387.0   7.594315
#         22        2496.000000       1913.000000          766.0   3.258486
#         23        1149.000000       1146.000000          585.0   3.234188
#         24        2096.000000        883.000000          386.0   5.082902
#         25        2421.000000       1448.000000          251.0   8.896414
#         26        3249.000000        980.000000          605.0   3.406612
#         27        1589.000000       1711.000000          643.0   3.765163
#         28        4219.000000       1486.000000          334.0   7.110778
#         29        1249.000000        442.000000          670.0   3.468657
# test    0         1069.000000        894.000000          255.0  11.796078
#         1         1548.000000        879.000000          677.0   3.754801
#         2         2367.000000       1268.000000          578.0   4.091696
#         3         1437.000000        566.000000          340.0   7.970588
#         4          858.000000        956.000000          768.0   2.990885
#         5         1073.000000        882.000000          488.0   5.036885
#         6         2182.000000       1301.000000          890.0   3.188764
#         7         2194.000000       1240.000000          431.0   6.765661
#         8         2761.000000       1200.000000          845.0   3.138462
#         9         1804.000000        424.000000          275.0  10.145455
#         10        2617.000000       1075.000000          668.0   3.622754
#         11        1992.000000       1382.000000          709.0   3.992948
#         12        2058.000000       1391.000000          812.0   2.428571
#         13        1059.000000        779.000000          340.0   7.461765
#         14        1609.000000       1090.000000          398.0   6.321608
#         15        2594.000000       1059.000000          487.0   6.316222
#         16        1576.000000        383.000000          238.0   8.268908
#         17        2522.000000        461.000000          257.0   7.700389
#         18        2801.000000        788.000000          512.0   5.128906
#         19        1894.000000       1047.000000          730.0   3.715068
#         20        1868.000000        278.000000          245.0  12.702041
#         21        1131.000000        367.000000          276.0  10.503623
#         22        2004.000000        632.000000          473.0   5.088795
#         23        2427.000000        327.000000          269.0   7.724907
#         24        2551.000000       1228.000000          651.0   4.497696
#         25        1046.000000        346.000000          284.0   8.137324
#         26        2552.000000        992.000000          771.0   3.780804
#         27        1281.000000       1009.000000          721.0   3.116505
#         28        1240.000000       1168.000000          677.0   4.143279
#         29        1625.000000       1034.000000          572.0   3.456294
#
#                  CPC        CTR  Conversion Rate Web Clicks  \
# control 0   0.324971   8.483471                   12.323907
#         1   0.216646   6.700264                    7.911192
#         2   0.360018   4.941121                    5.870361
#         3   0.632953   4.205659                    5.005307
#         4   0.322916   6.191815                    8.018487
#         5   0.765392   3.692838                    4.577377
#         6   0.963636   1.857546                    2.064888
#         7   0.261708   7.983373                   11.132067
#         8   0.453856   5.108298                    6.531361
#         9   0.943786   1.935829                    2.495151
#         10  0.306010   7.060487                    8.489926
#         11  0.774808   2.566037                    2.987354
#         12  0.411504   7.910968                    9.607998
#         13  0.414731   3.112607                    3.810945
#         14  0.566585   3.685498                    4.777564
#         15  0.387443   7.329461                   12.188805
#         16  0.328455   5.541250                    6.222423
#         17  0.258652   6.687751                    7.514660
#         18  0.700486   3.434980                    4.560221
#         19  1.037626   2.272767                    3.278855
#         20  0.316816   7.623168                    9.505119
#         21  0.429490   6.473677                    7.936858
#         22  0.565986   3.395442                    4.030600
#         23  0.463158   5.633317                    7.857734
#         24  0.463392   3.618618                    4.217215
#         25  0.410856   4.351586                    5.521578
#         26  0.417122   4.720190                    5.395342
#         27  0.385080   4.438279                    4.994677
#         28  0.292236   8.830912                   10.954011
#         29  0.498927   4.184860                    5.255438
# test    0   0.990125   7.681416                    8.481295
#         1   0.545845   4.623755                    5.104345
#         2   0.299937  11.222123                   17.445462
#         3   0.642789   5.374055                   16.254771
#         4   0.391779   5.129708                    6.162627
#         5   0.328259  17.542873                   23.779733
#         6   0.672353   7.818694                   10.014710
#         7   0.405902  21.337135                   35.654375
#         8   0.321104  18.147261                   26.137730
#         9   0.343385   8.547773                   10.203185
#         10  0.645333   4.483876                    5.260500
#         11  0.342570   6.632903                   77.976977
#         12  0.260571  11.496802                   15.279320
#         13  0.635362   7.091858                   15.368332
#         14  0.503905   5.292671                    6.550860
#         15  0.452353   6.379944                    8.354937
#         16  0.248799   8.253081                   14.543382
#         17  0.286438  12.882234                   15.977891
#         18  0.344755  33.821766                   71.200224
#         19  0.448264  15.328097                   18.969680
#         20  0.568817   4.089825                    4.981153
#         21  0.654254  12.750345                   15.863526
#         22  0.474099   8.421524                   10.292120
#         23  0.290386  19.525239                   23.470760
#         24  0.814238   2.982351                    3.393157
#         25  0.604974   4.725325                    6.202406
#         26  0.452991   5.772905                    6.982498
#         27  0.275909  14.908379                   19.734897
#         28  0.366619  11.344226                   17.702862
#         29  0.449420   3.659642                    4.921683
#
#             Conversion Rate Purchase
# control 0                   8.808438
#         1                   6.300863
#         2                   5.716042
#         3                  11.092985
#         4                   9.185947
#         5                  18.967229
#         6                  18.901515
#         7                   6.363636
#         8                   8.083253
#         9                  32.235397
#         10                  5.837532
#         11                 26.528567
#         12                 11.687519
#         13                 17.429772
#         14                  7.475490
#         15                  8.384380
#         16                  3.349427
#         17                  3.350338
#         18                 14.624933
#         19                 11.598138
#         20                 14.057283
#         21                  5.655414
#         22                 17.369615
#         23                 14.320685
#         24                  9.116675
#         25                  4.618215
#         26                 12.244485
#         27                 10.227453
#         28                  4.109758
#         29                 14.383856
# test    0                   8.393680
#         1                  14.537256
#         2                   7.330374
#         3                   8.064516
#         4                  13.099096
#         5                   6.517094
#         6                  21.085051
#         7                   5.999443
#         8                  10.231263
#         9                   3.384615
#         10                 17.813333
#         11                  8.579380
#         12                 10.729387
#         13                  8.514901
#         14                  7.971160
#         15                  7.161765
#         16                  3.008850
#         17                  3.719786
#         18                  6.721806
#         19                 12.066116
#         20                  4.478158
#         21                  6.228842
#         22                  9.316526
#         23                  3.759083
#         24                 18.103448
#         25                  7.434555
#         26                 11.981352
#         27                  8.853143
#         28                  8.848517
#         29                 13.002955

# %% [markdown]
# ## Проведение статистических тестов

# %% [markdown]
# Теперь будем проводить тесты. Выберем t-test для сравнения среднего значения рассчитанных метрик по 2 рекламным кампаниям

# %% [markdown]
# ### CAC – client acquisition cost

# %% [markdown]
# Сначала проверим нормальность распределения, используя критерий Шапиро-Уилка. Нулевая гипотеза: данные в группах распределены нормально, альтернативная гипотеза: данные в группах не распределены нормально

# %%
from scipy.stats import shapiro
res = []
n = 0
while n < 500:
    n += 1
    cac = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['CAC'].mean()
    res.append(cac)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9972400069236755, pvalue=0.5708360075950623)

# %%
res = []
n = 0
while n < 500:
    n += 1
    cac = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['CAC'].mean()
    res.append(cac)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9950408935546875, pvalue=0.10932093858718872)

# %% [markdown]
# Так как p-value > 0.05 в обоих случаях, мы не можем отвергнуть нулевую гипотезу. Данные распределены нормально

# %% [markdown]
# Теперь проверим данные в группах на равенство дисперсий при помощи критерия Левене. Нулевая гипотеза: дисперсии в выборках не имеют значительных различий, альтернативная гипотеза: дисперсии в выборках значительно различаются

# %%
from scipy.stats import levene
cac_control = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['CAC']
cac_test = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['CAC']
levene(cac_control, cac_test)
# Out:
# LeveneResult(statistic=0.7800621420811126, pvalue=0.3846426823232336)

# %% [markdown]
# p-value > 0.05 => не можем отвергнуть нулевую гипотезу. Дисперсии в выборках не имеют значительных различий

# %% [markdown]
# Теперь можно проводить t-test. Нулевая гипотеза: в значениях CAC на двух группах нет значительных различий

# %%
from scipy.stats import ttest_ind
ttest_ind(cac_control, cac_test, equal_var=True)
# Out:
# Ttest_indResult(statistic=-1.0087827116536705, pvalue=0.32171750193229043)

# %% [markdown]
# По результатам p-value>0.05, поэтому мы не можем отвергнуть нулевую гипотезу

# %% [markdown]
# ### CPC – cost per click

# %% [markdown]
# Проделаем аналогичные действия, рассматривая метрику CPC. Начнем с нормальности распределений. Нулевая гипотеза: данные распределены нормально

# %%
res = []
n = 0
while n < 500:
    n += 1
    cpc = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['CPC'].mean()
    res.append(cpc)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9956243634223938, pvalue=0.1763729602098465)

# %%
res = []
n = 0
while n < 500:
    n += 1
    cpc = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['CPC'].mean()
    res.append(cpc)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9973397850990295, pvalue=0.605265736579895)

# %% [markdown]
# Мы не можем отвергнуть нулевую гипотезу. Теперь к сравнению дисперсий:

# %%
cpc_control = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['CPC']
cpc_test = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['CPC']
levene(cpc_control, cpc_test)
# Out:
# LeveneResult(statistic=0.04476609541681262, pvalue=0.8339672300429609)

# %% [markdown]
# Дисперсии не имеют значимых различий, поэтому можно переходить к t-тесту. Нулевая гипотеза: значимых различий в средних значениях CPC нет

# %%
ttest_ind(cpc_control, cpc_test, equal_var=True)
# Out:
# Ttest_indResult(statistic=0.03731114605561646, pvalue=0.9705016657702299)

# %% [markdown]
# И снова мы не можем отвергнуть нулевую гипотезу: значимых различий в CPC нет

# %% [markdown]
# ### CTR – click-through rate

# %% [markdown]
# Переходим к CTR. Проверяем нормальность распределений:

# %%
res = []
n = 0
while n < 500:
    n += 1
    ctr = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['CTR'].mean()
    res.append(ctr)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.997113049030304, pvalue=0.5280595421791077)

# %%
res = []
n = 0
while n < 500:
    n += 1
    ctr = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['CTR'].mean()
    res.append(ctr)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9963651299476624, pvalue=0.31440553069114685)

# %% [markdown]
# Данные распределены нормально. Посмотрим на разницу дисперсий:

# %%
ctr_control = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['CTR']
ctr_test = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['CTR']
levene(ctr_control, ctr_test)
# Out:
# LeveneResult(statistic=5.341722283483085, pvalue=0.02839868509679126)

# %% [markdown]
# Мы не можем принять гипотезу о равенстве дисперсий. Отразим это в t-тесте. Нулевая гипотеза: значимых различий между CTR нет

# %%
ttest_ind(ctr_control, ctr_test, equal_var=False)
# Out:
# Ttest_indResult(statistic=-2.888173713440709, pvalue=0.009943356574390601)

# %% [markdown]
# p-value < 0.05, поэтому мы должны отвергнуть нулевую гипотезу => различия в показателе есть.

# %%
print(total[total['Campaign Name'] == 'Control Campaign']['CTR'].mean(), total[total['Campaign Name'] == 'Test Campaign']['CTR'].mean())
# Out:
# 5.13240238623555 10.242259642726077

# %% [markdown]
# Исходя из средних значений CTR на 2 группах и результата t-теста, можем сделать вывод, что CTR на тестовой группе значительно выше

# %% [markdown]
# ### Conversion Rate Web Clicks

# %% [markdown]
# Перейдем к конверсии с целевым действием "клик на сайт"

# %%
res = []
n = 0
while n < 500:
    n += 1
    cr_webclicks = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['Conversion Rate Web Clicks'].mean()
    res.append(cr_webclicks)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9979416728019714, pvalue=0.8115562200546265)

# %%
res = []
n = 0
while n < 500:
    n += 1
    cr_webclicks = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['Conversion Rate Web Clicks'].mean()
    res.append(cr_webclicks)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9902125597000122, pvalue=0.0020885386038571596)

# %% [markdown]
# Видим, что сравнить средние значения по такой конверсии при помощи t-теста не получится, так как данные в тестовой группе не распределены нормально

# %% [markdown]
# ### Conversion Rate Purchase

# %% [markdown]
# Попробуем посмотреть на данные по конверсии с целевым действием "Покупка"

# %%
res = []
n = 0
while n < 500:
    n += 1
    cr_purchase = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['Conversion Rate Purchase'].mean()
    res.append(cr_purchase)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9969278573989868, pvalue=0.46848344802856445)

# %%
res = []
n = 0
while n < 500:
    n += 1
    cr_purchase = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['Conversion Rate Purchase'].mean()
    res.append(cr_purchase)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9964435696601868, pvalue=0.3332498371601105)

# %% [markdown]
# Здесь мы можем использовать t-тест, так как данные по тестам распределены нормально. Перейдем к сравнению дисперсий

# %%
cr_purchase_control = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['Conversion Rate Purchase']
cr_purchase_test = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['Conversion Rate Purchase']
levene(cr_purchase_control, cr_purchase_test)
# Out:
# LeveneResult(statistic=0.6821004867462536, pvalue=0.41584636008646925)

# %% [markdown]
# Дисперсии не различаются значительно. Посмотрим на результаты t-теста: нулевая гипотеза – конверсии с целевым действием "Покупка" не различаются значительно

# %%
ttest_ind(ctr_control, ctr_test, equal_var=True)
# Out:
# Ttest_indResult(statistic=-2.888173713440709, pvalue=0.0073933294926752996)

# %% [markdown]
# p-value<0.05 => мы должны принять альтернативную гипотезу, то есть что конверсии с целевым действием "Покупка" имеют значительные различия

# %%
print(total[total['Campaign Name'] == 'Control Campaign']['Conversion Rate Purchase'].mean(), total[total['Campaign Name'] == 'Test Campaign']['Conversion Rate Purchase'].mean())
# Out:
# 11.400828018355812 9.2311817032836

# %% [markdown]
# Видим, что по результатам t-теста и средним значениям метрики на контрольной и тестовой группах различаются следующим образом: у контрольной группы среднее значение по контрольной группе значительно превышает среднее значение по тестовой группе

# %% [markdown]
# Однако интересно заметить, что среднее количество покупок в первой и второй группе оказалось приблизительно одинаковым:

# %%
print(total[total['Campaign Name'] == 'Control Campaign']['# of Purchase'].mean(), total[total['Campaign Name'] == 'Test Campaign']['# of Purchase'].mean())
# Out:
# 522.7666666666667 521.2333333333333

# %% [markdown]
# Проверим, случайный это результат или нет, при помощи еще одного t-теста

# %%
res = []
n = 0
while n < 500:
    n += 1
    purchase = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['# of Purchase'].mean()
    res.append(purchase)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9950816035270691, pvalue=0.1130741536617279)

# %%
res = []
n = 0
while n < 500:
    n += 1
    purchase = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['# of Purchase'].mean()
    res.append(purchase)
shapiro(res)
# Out:
# ShapiroResult(statistic=0.9961179494857788, pvalue=0.26057928800582886)

# %%
purchase_control = total[total['Campaign Name'] == 'Control Campaign'].sample(15)['# of Purchase']
purchase_test = total[total['Campaign Name'] == 'Test Campaign'].sample(15)['# of Purchase']
levene(purchase_control, purchase_test)
# Out:
# LeveneResult(statistic=0.05457647395079816, pvalue=0.8169826404804246)

# %% [markdown]
# Нулевая гипотеза: среднее значение покупок в день не различается значительно между группами

# %%
ttest_ind(purchase_control, purchase_test, equal_var=True)
# Out:
# Ttest_indResult(statistic=0.09972429546875311, pvalue=0.9212738023575912)

# %% [markdown]
# Действительно, среднее значение покупок в день не различается значительно между группами, хотя средние значения конверсии с целевым действием "Покупка" значительно выше в контрольной группе

# %% [markdown]
# ## Итоги

# %% [markdown]
# Теперь мы можем сравнить эффективность двух рекламных кампаний, исходя из результатов проведенных статистических тестов и сравнения по различным метрикам.\
# \
# Получилось, что контрольная рекламная кампания показала более высокое значение конверсии с целевым действием покупки, то есть те пользователи, которые переходили по рекламному баннеру на наш сайт, в среднем чаще совершали покупки по сравнению с пользователями, которые переходили по рекламному баннеру второй рекламной кампании. Тем не менее мы проверили, что среднее количество покупок в день практически одинаково по группам: иными словами, вторая рекламная кампания привлекает больше клиентов на сайт (среднее значение ctr в тестовой группе значительно выше), и несмотря на то что средняя конверсия с целевым действием "Покупка" в тестовой группе ниже, за счет большего числа клиентов на сайт среднее значение покупок не отличается значительно от среднего значения покупок в контрольной группе\
# \
# Исходя из этих результатов, можно сделать вывод, что вторая рекламная кампания была успешнее, поскольку среднее количество заказов не отличается значительно, однако по результатам второй кампании больше пользователей переходит на сайт, из-за чего больше людей узнают о наших продуктах
